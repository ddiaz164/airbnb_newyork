# %%
import pandas as pd
import numpy as np
import folium
import json
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import NMF, PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
import xgboost as xgb
from src.nlp_helpers import *
from src.model_helpers import *

# %%
data = pd.read_csv('data/AB_NYC_2019.csv')

# %%
data['last_review'].fillna('None', inplace=True)
data['reviews_per_month'].fillna(0.0, inplace=True)
data['name'].fillna('Unknown', inplace=True)
data['host_name'].fillna('Unknown', inplace=True)

# %%
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2            None               0.00                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890        None               0.00                               2
# 48891        None               0.00                               2
# 48892        None               0.00                               1
# 48893        None               0.00                               6
# 48894        None               0.00                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     48895 non-null  object
#  13  reviews_per_month               48895 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
data = data.merge(pd.get_dummies(data['room_type']), left_index=True, right_index=True)
data.drop(columns = 'room_type', inplace=True)

# %%
vectorizer, vocab = text_vectorizer(data['name'], use_tfidf=False, use_stemmer=True)
X = vectorizer(data['name'])
# Out:
# /Users/skylarenglish/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:507: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"

# %%
X.shape
# Out:
# (48895, 7287)

# %%
nmf = NMF(n_components=400, max_iter=10, alpha=0.0)
W = nmf.fit_transform(X)
H = nmf.components_
print('reconstruction error: ', nmf.reconstruction_err_)
# Out:
# reconstruction error:  283.9259227394941

# %%
hand_labels = hand_label_topics(H, vocab)
# Out:
# topic 1
# --> room nice avail furnish small
#
# topic 2
# --> bedroom master furnish avail nice
#
# topic 3
# --> apart awesom cosi stylish chic
#
# topic 4
# --> apt lux 3br bdr stylish
#
# topic 5
# --> privat entranc terrac backyard patio
#
# topic 6
# --> cozi warm conveni getaway super
#
# topic 7
# --> park slope ditma sunset free
#
# topic 8
# --> brooklyn ny oasi downtown gem
#
# topic 9
# --> 2 bd sleep block stori
#
# topic 10
# --> studio gym furnish alcov ue
#
# topic 11
# --> manhattan downtown stop upper 20
#
# topic 12
# --> 1 bd block bdr stop
#
# topic 13
# --> spaciou bk backyard flat 3br
#
# topic 14
# --> east villag street 1bd st
#
# topic 15
# --> williamsburg l south bedford e
#
# topic 16
# --> sunni bedstuy friendli le top
#
# topic 17
# --> home away sweet famili profession
#
# topic 18
# --> beauti stuy area furnish ue
#
# topic 19
# --> w blueground gym backyard doorman
#
# topic 20
# --> upper side 107 gem stylish
#
# topic 21
# --> locat conveni ideal perfectli excel
#
# topic 22
# --> near columbia univers metro sq
#
# topic 23
# --> bed stuy size king sofa
#
# topic 24
# --> nyc downtown center stay experi
#
# topic 25
# --> loft tribeca design style like
#
# topic 26
# --> new brand build condo step
#
# topic 27
# --> heart le bk slope downtown
#
# topic 28
# --> larg extra furnish window patio
#
# topic 29
# --> new york unit multi downtown
#
# topic 30
# --> luxuri build condo high gym
#
# topic 31
# --> villag greenwich e gem flat
#
# topic 32
# --> modern mid centuri chic condo
#
# topic 33
# --> bright airi bk open cheer
#
# topic 34
# --> 1br blueground doorman gym sonder
#
# topic 35
# --> min 15 20 10 30
#
# topic 36
# --> charm uw le 1bd ue
#
# topic 37
# --> bushwick l trendi ridgewood hip
#
# topic 38
# --> 3 stop stori bdr rm
#
# topic 39
# --> quiet neighborhood street safe area
#
# topic 40
# --> central park grand uw walk
#
# topic 41
# --> view river skylin stun penthous
#
# topic 42
# --> midtown 45 wyndham presidenti doorman
#
# topic 43
# --> brownston histor classic stuy bedstuy
#
# topic 44
# --> one block stop kind fee
#
# topic 45
# --> subway block step next walk
#
# topic 46
# --> great neighborhood area price next
#
# topic 47
# --> height crown hamilton washington morningsid
#
# topic 48
# --> clean safe nice free super
#
# topic 49
# --> garden carrol slope level oasi
#
# topic 50
# --> harlem histor south spanish gem
#
# topic 51
# --> bdrm le backyard condo avail
#
# topic 52
# --> train l block step j
#
# topic 53
# --> huge terrac backyard next yard
#
# topic 54
# --> bath full master dryer washer
#
# topic 55
# --> renov newli fulli furnish stylish
#
# topic 56
# --> queen size ny flush gowanu
#
# topic 57
# --> hill clinton cobbl murray boerum
#
# topic 58
# --> close everyth metro columbia transport
#
# topic 59
# --> duplex terrac backyard penthous slope
#
# topic 60
# --> prime area le ave slope
#
# topic 61
# --> hous famili beach hotel town
#
# topic 62
# --> citi island long center 20
#
# topic 63
# --> comfort conveni stay columbia style
#
# topic 64
# --> 2br 2ba furnish 2bath ue
#
# topic 65
# --> love area flat uw spread
#
# topic 66
# --> suit guest servic fee master
#
# topic 67
# --> amaz step area away male
#
# topic 68
# --> chelsea doorman blueground 21 chic
#
# topic 69
# --> space outdoor event open peac
#
# topic 70
# --> floor top full 1st ground
#
# topic 71
# --> big appl ny tv oasi
#
# topic 72
# --> jfk lga airport 10 beach
#
# topic 73
# --> kitchen hell' hell full stock
#
# topic 74
# --> soho nolita littl itali le
#
# topic 75
# --> 4 gym doorman sleep blueground
#
# topic 76
# --> astoria ny nice lic chic
#
# topic 77
# --> bathroom master full privat ensuit
#
# topic 78
# --> fill light sun drench art
#
# topic 79
# --> lower side east chinatown gem
#
# topic 80
# --> west street 1bd lux columbia
#
# topic 81
# --> comfi conveni couch getaway stay
#
# topic 82
# --> gorgeou terrac flat penthous step
#
# topic 83
# --> best area neighborhood valu deal
#
# topic 84
# --> prospect park step next leffert
#
# topic 85
# --> 5 walk star sleep min
#
# topic 86
# --> entir uw entranc flat basement
#
# topic 87
# --> share femal male guest profession
#
# topic 88
# --> greenpoint bk gem trendi peac
#
# topic 89
# --> place stay nice sutton friendli
#
# topic 90
# --> br green fort furnish cumberland
#
# topic 91
# --> sonder stock rooftop exchang gym
#
# topic 92
# --> perfect famili stay friendli getaway
#
# topic 93
# --> minut 15 10 away 20
#
# topic 94
# --> two backyard bridg block stori
#
# topic 95
# --> townhous histor famili design district
#
# topic 96
# --> balconi doorman gym chic penthous
#
# topic 97
# --> live block uw like le
#
# topic 98
# --> artist flat retreat bedstuy green
#
# topic 99
# --> time squar sq union step
#
# topic 100
# --> cute build state empir doorman

# %%
print(data[data['name'].index==100])
analyze(100, data['name'], W, hand_labels)
# Out:
#         id                                              name  host_id  \
# 100  22918  loft bed - near transportation-15min to times sq    32294
#
#            host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 100  Ssameer Or Trip           Manhattan        Harlem  40.82279  -73.95139
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 100     60               3                 11  2019-01-03               0.87
#
#      calculated_host_listings_count  availability_365  Entire home/apt  \
# 100                               3               219                0
#
#      Private room  Shared room
# 100             1            0
# --> 0.00% 1
# --> 0.00% 2
# --> 0.00% 3
# --> 0.00% 4
# --> 0.00% 5
# --> 0.00% 6
# --> 0.00% 7
# --> 0.00% 8
# --> 0.00% 9
# --> 0.00% 10
# --> 0.00% 11
# --> 0.00% 12
# --> 0.00% 13
# --> 0.00% 14
# --> 0.00% 15
# --> 0.00% 16
# --> 0.00% 17
# --> 0.00% 18
# --> 0.00% 19
# --> 0.00% 20
# --> 0.00% 21
# --> 1.16% 22
# --> 13.70% 23
# --> 0.00% 24
# --> 75.47% 25
# --> 0.00% 26
# --> 0.00% 27
# --> 0.00% 28
# --> 0.00% 29
# --> 0.00% 30
# --> 0.00% 31
# --> 0.00% 32
# --> 0.00% 33
# --> 0.00% 34
# --> 0.00% 35
# --> 0.00% 36
# --> 0.00% 37
# --> 0.00% 38
# --> 0.00% 39
# --> 0.00% 40
# --> 0.00% 41
# --> 0.00% 42
# --> 0.00% 43
# --> 0.00% 44
# --> 0.00% 45
# --> 0.00% 46
# --> 0.00% 47
# --> 0.00% 48
# --> 0.00% 49
# --> 0.00% 50
# --> 0.00% 51
# --> 0.00% 52
# --> 0.00% 53
# --> 0.00% 54
# --> 0.00% 55
# --> 0.00% 56
# --> 0.00% 57
# --> 0.00% 58
# --> 0.00% 59
# --> 0.00% 60
# --> 0.00% 61
# --> 0.00% 62
# --> 0.00% 63
# --> 0.00% 64
# --> 0.00% 65
# --> 0.00% 66
# --> 0.00% 67
# --> 0.00% 68
# --> 0.00% 69
# --> 0.00% 70
# --> 0.00% 71
# --> 0.00% 72
# --> 0.00% 73
# --> 0.00% 74
# --> 0.00% 75
# --> 0.00% 76
# --> 0.00% 77
# --> 0.00% 78
# --> 0.00% 79
# --> 0.00% 80
# --> 0.00% 81
# --> 0.00% 82
# --> 0.00% 83
# --> 0.00% 84
# --> 0.00% 85
# --> 0.00% 86
# --> 0.00% 87
# --> 0.00% 88
# --> 0.00% 89
# --> 0.00% 90
# --> 0.00% 91
# --> 0.00% 92
# --> 0.00% 93
# --> 0.00% 94
# --> 0.00% 95
# --> 0.00% 96
# --> 0.00% 97
# --> 0.00% 98
# --> 9.66% 99
# --> 0.00% 100

# %%
labels = analyze_all(data, W, hand_labels)

# %%
data['labels'] = labels
data = data.merge(pd.get_dummies(data['labels']), left_index=True, right_index=True)
data.drop(columns = 'labels', inplace=True)

# %%
X = np.column_stack((data['latitude'], data['longitude'], data['minimum_nights'], data['number_of_reviews'], data['reviews_per_month'], data['calculated_host_listings_count'], data['availability_365'], data['Entire home/apt'], data['Private room'], data['Shared room'], data.iloc[:,-100:]))
y = data['price'].values

# %%
X[0]
# Out:
# array([ 4.064749e+01, -7.397237e+01,  1.000000e+00,  9.000000e+00,
#         2.100000e-01,  6.000000e+00,  3.650000e+02,  0.000000e+00,
#         1.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  1.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,
#         0.000000e+00,  0.000000e+00])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=0.3, learning_rate=0.1, max_depth=5, alpha=10, n_estimators=10)
xg_reg.fit(X_train, y_train)
preds = xg_reg.predict(X_test)

# %%
cross_val(xg_reg, X_train, y_train, 10)
# Out:
# XGBRegressor              Train CV | MSE: 54984.191 | R2: 0.034
# (54984.19053835222, 0.03357141065138105)

# %%
data_dmatrix = xgb.DMatrix(data=X, label=y)

# %%
params = {'objective':'reg:squarederror', 'colsample_bytree': 0.3, 'learning_rate':0.1, 'max_depth':5, 'alpha':10}
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=5, num_boost_round=50, early_stopping_rounds=10, metrics='rmse', as_pandas=True, seed=123)

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0       275.310693        4.920002      274.780920      20.385923
# 1       267.365185        4.867119      267.325528      21.049661
# 2       260.198260        5.307295      260.495541      21.654510
# 3       253.997412        5.798819      254.944678      22.157685
# 4       248.588666        5.871947      249.814789      22.544130

# %%
print(cv_results['test-rmse-mean'].tail(1))
# Out:
# 49    222.302222
# Name: test-rmse-mean, dtype: float64

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [20,15]
plt.show()

# %%
gdbr = GradientBoostingRegressor(learning_rate=0.1, loss='ls', n_estimators=1000)
#rf = RandomForestRegressor(n_estimators=100, max_depth=10, n_jobs=-1)
#abr = AdaBoostRegressor(DecisionTreeRegressor(), learning_rate=0.1, loss='linear', n_estimators=100)

# %%
cross_val(gdbr, X_train, y_train, 5)
#cross_val(rf, X_train, y_train, 5)
#cross_val(abr, X_train, y_train, 5)
# Out:
# GradientBoostingRegressor Train CV | MSE: 55025.701 | R2: 0.027
# (55025.70108512929, 0.026550213195911155)
