# %%
import pandas as pd
import numpy as np
import folium
import json
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import NMF, PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
import xgboost as xgb
from src.nlp_helpers import *
from src.model_helpers import *

# %%
data = pd.read_csv('data/AB_NYC_2019.csv')

# %%
data['last_review'].fillna('None', inplace=True)
data['reviews_per_month'].fillna(0.0, inplace=True)
data['name'].fillna('Unknown', inplace=True)
data['host_name'].fillna('Unknown', inplace=True)

# %%
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2            None               0.00                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890        None               0.00                               2
# 48891        None               0.00                               2
# 48892        None               0.00                               1
# 48893        None               0.00                               6
# 48894        None               0.00                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48895 non-null object
# host_id                           48895 non-null int64
# host_name                         48895 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       48895 non-null object
# reviews_per_month                 48895 non-null float64
# calculated_host_listings_count    48895 non-null int64
# availability_365                  48895 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
data = data.merge(pd.get_dummies(data['room_type']), left_index=True, right_index=True)
data.drop(columns = 'room_type', inplace=True)

# %%
vectorizer, vocab = text_vectorizer(data['name'], use_tfidf=True, use_stemmer=False)
X = vectorizer(data['name'])

# %%
nmf = NMF(n_components=50, max_iter=10, alpha=0.0)
W = nmf.fit_transform(X)
H = nmf.components_
print('reconstruction error: ', nmf.reconstruction_err_)
# Out:
# reconstruction error:  178.52750923042174

# %%
hand_labels = hand_label_topics(H, vocab)
# Out:
# topic 1
# --> bedroom private two master bathroom
#
# topic 2
# --> room private bathroom bath entrance
#
# topic 3
# --> east village greenwich lower cute
#
# topic 4
# --> apartment entire two gorgeous shared
#
# topic 5
# --> park central slope prospect next
#
# topic 6
# --> brooklyn home house oasis ny
#
# topic 7
# --> cozy room astoria warm place
#
# topic 8
# --> williamsburg prime south east bedford
#
# topic 9
# --> studio chelsea private uws alcove
#
# topic 10
# --> spacious room light backyard bk
#
# topic 11
# --> min 15 mins 20 5
#
# topic 12
# --> side upper east lower west
#
# topic 13
# --> sunny room big hill clinton
#
# topic 14
# --> beautiful room astoria home townhouse
#
# topic 15
# --> manhattan minutes downtown home upper
#
# topic 16
# --> 2 bath br bedrooms beds
#
# topic 17
# --> 1 br bdrm home block
#
# topic 18
# --> heart astoria chelsea les lovely
#
# topic 19
# --> apt entire 2br gorgeous floor
#
# topic 20
# --> location prime best perfect amazing
#
# topic 21
# --> bushwick room l trendy train
#
# topic 22
# --> loft artist tribeca soho designer
#
# topic 23
# --> west village upper greenwich prime
#
# topic 24
# --> large extra furnished 2br astoria
#
# topic 25
# --> new york city brand home
#
# topic 26
# --> bright big airy room balcony
#
# topic 27
# --> nyc home away view best
#
# topic 28
# --> charming house townhouse les astoria
#
# topic 29
# --> near columbia train jfk prospect
#
# topic 30
# --> modern townhouse mid century condo
#
# topic 31
# --> bed stuy queen bath size
#
# topic 32
# --> harlem home away historic central
#
# topic 33
# --> greenpoint soho amazing nolita bk
#
# topic 34
# --> w backyard balcony bathroom private
#
# topic 35
# --> heights crown prospect washington hamilton
#
# topic 36
# --> quiet home neighborhood space street
#
# topic 37
# --> brownstone historic floor classic bedstuy
#
# topic 38
# --> square times time union sq
#
# topic 39
# --> luxury building condo doorman views
#
# topic 40
# --> midtown east 45 wyndham suite
#
# topic 41
# --> one bedroom block stop suite
#
# topic 42
# --> 1br sonder chelsea stock exchange
#
# topic 43
# --> great location space neighborhood room
#
# topic 44
# --> clean comfortable comfy convenient safe
#
# topic 45
# --> subway steps house next block
#
# topic 46
# --> close everything train comfy jfk
#
# topic 47
# --> garden lovely hill slope townhouse
#
# topic 48
# --> 3 duplex br bedrooms bath
#
# topic 49
# --> renovated newly fully furnished townhouse
#
# topic 50
# --> huge terrace space duplex backyard

# %%
print(data[data['name'].index==100])
analyze(100, data['name'], W, hand_labels)
# Out:
#         id                                              name  host_id  \
# 100  22918  loft bed - near transportation-15min to times sq    32294
#
#            host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 100  Ssameer Or Trip           Manhattan        Harlem  40.82279  -73.95139
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 100     60               3                 11  2019-01-03               0.87
#
#      calculated_host_listings_count  availability_365  Entire home/apt  \
# 100                               3               219                0
#
#      Private room  Shared room
# 100             1            0
# --> 0.18% 1
# --> 0.18% 2
# --> 0.18% 3
# --> 0.18% 4
# --> 0.18% 5
# --> 0.18% 6
# --> 0.18% 7
# --> 0.18% 8
# --> 0.18% 9
# --> 0.18% 10
# --> 0.18% 11
# --> 0.18% 12
# --> 0.18% 13
# --> 0.18% 14
# --> 0.19% 15
# --> 0.18% 16
# --> 0.18% 17
# --> 0.18% 18
# --> 0.18% 19
# --> 0.18% 20
# --> 0.18% 21
# --> 12.95% 22
# --> 0.18% 23
# --> 0.18% 24
# --> 0.18% 25
# --> 0.18% 26
# --> 0.18% 27
# --> 0.18% 28
# --> 12.69% 29
# --> 0.19% 30
# --> 22.26% 31
# --> 0.18% 32
# --> 0.18% 33
# --> 0.18% 34
# --> 0.18% 35
# --> 0.18% 36
# --> 0.18% 37
# --> 43.66% 38
# --> 0.18% 39
# --> 0.19% 40
# --> 0.18% 41
# --> 0.18% 42
# --> 0.18% 43
# --> 0.18% 44
# --> 0.18% 45
# --> 0.18% 46
# --> 0.18% 47
# --> 0.18% 48
# --> 0.18% 49
# --> 0.19% 50

# %%
labels = analyze_all(data, W, hand_labels)

# %%
data['labels'] = labels
data = data.merge(pd.get_dummies(data['labels']), left_index=True, right_index=True)
data.drop(columns = 'labels', inplace=True)

# %%
X = np.column_stack((data['latitude'], data['longitude'], data['minimum_nights'], data['number_of_reviews'], data['reviews_per_month'], data['calculated_host_listings_count'], data['availability_365'], data['Entire home/apt'], data['Private room'], data['Shared room'], data.iloc[:,-50:]))
y = data['price'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=0.3, learning_rate=0.1, max_depth=5, alpha=10, n_estimators=10)
xg_reg.fit(X_train, y_train)
preds = xg_reg.predict(X_test)

# %%
cross_val(xg_reg, X_train, y_train, 10)
# Out:
# /home/david/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# XGBRegressor              Train CV | MSE: 53235.873 | R2: 0.039
# (53235.87312268447, 0.039427475939969994)

# %%
data_dmatrix = xgb.DMatrix(data=X, label=y)

# %%
params = {'objective':'reg:squarederror', 'colsample_bytree': 0.3, 'learning_rate':0.1, 'max_depth':5, 'alpha':10}
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3, num_boost_round=50, early_stopping_rounds=10, metrics='rmse', as_pandas=True, seed=123)

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0       275.308726       10.436048      275.084737      21.515733
# 1       266.743062        9.133984      267.362630      22.614918
# 2       260.303650        8.770889      261.098190      23.413249
# 3       253.811071        8.552192      254.870478      24.237132
# 4       248.361110        8.846825      250.043258      24.228801

# %%
print(cv_results['test-rmse-mean'].tail(1))
# Out:
# 49    219.231537
# Name: test-rmse-mean, dtype: float64

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [20,15]
plt.show()

# %%
# Out:
# (60,)

# %%
gdbr = GradientBoostingRegressor(learning_rate=0.1, loss='ls', n_estimators=100)
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1)
abr = AdaBoostRegressor(DecisionTreeRegressor(), learning_rate=0.1, loss='linear', n_estimators=100)

# %%
cross_val(gdbr, X_train, y_train, 10)
cross_val(rf, X_train, y_train, 10)
cross_val(abr, X_train, y_train, 10)
# Out:
# GradientBoostingRegressor Train CV | MSE: 46657.000 | R2: 0.170
# RandomForestRegressor     Train CV | MSE: 48236.740 | R2: 0.132
